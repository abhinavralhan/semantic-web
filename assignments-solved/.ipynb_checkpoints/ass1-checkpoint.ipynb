# %%
import requests


URI = "https://dbpedia.org/person/Hermann_Knoblauch"
res = requests.get(url = URI)
print(f"URL: {URI}\n\nResponds code: {res.status_code}\n\nResponds content: {res.content}\n\n\n")

URI = "https://dbpedia.org/resource/Hermann_Knoblauch"
res = requests.get(url = URI)
print(f"URL: {URI}\n\nResponds code: {res.status_code}\n\nResponds content: {res.content}\n")
# Out:
# URL: https://dbpedia.org/person/Hermann_Knoblauch
#
# Responds code: 404
#
# Responds content: b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML//EN">\n<html>\n  <head>\n    <title>Error HTTP/1.1 404 File not found</title>\n  </head>\n  <body>\n    <h3>Error HTTP/1.1 404 File not found</h3><pre>\nThe requested URL was not found    URI  = \'/person/Hermann_Knoblauch\'\n  </pre></body></html>\n'
#
#
#
# URL: https://dbpedia.org/resource/Hermann_Knoblauch
#
# Responds code: 200
#
# Responds content: b'<!DOCTYPE html>\n<html\n    prefix="\n        dbp: http://dbpedia.org/property/\n        dbo: http://dbedia.org/ontology/\n        dct: http://purl.org/dc/terms/\n        dbd: http://dbpedia.org/datatype/\n\tog:  https://ogp.me/ns#\n\t"\n>\n\n\n<!-- header -->\n<head>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n\n    <title>About: Hermann Knoblauch</title>\n\n    <!-- Links -->\n    <link rel="alternate" type="application/rdf+xml" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.rdf" title="Structured Descriptor Document (RDF/XML format)" />\n    <link rel="alternate" type="text/n3" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.n3" title="Structured Descriptor Document (N3 format)" />\n    <link rel="alternate" type="text/turtle" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.ttl" title="Structured Descriptor Document (Turtle format)" />\n    <link rel="alternate" type="application/json+rdf" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.jrdf" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/json" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.json" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/atom+xml" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.atom" title="OData (Atom+Feed format)" />\n    <link rel="alternate" type="text/plain" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.ntriples" title="Structured Descriptor Document (N-Triples format)" />\n    <link rel="alternate" type="text/csv"   \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fcsv" title="Structured Descriptor Document (CSV format)" />\n    \n    <link rel="alternate" type="application/microdata+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=application%2Fmicrodata%2Bjson" title="Structured Descriptor Document (Microdata/JSON format)" />\n    <link rel="alternate" type="text/html" \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fhtml" title="Structured Descriptor Document (Microdata/HTML format)" />\n    <link rel="alternate" type="application/ld+json" \t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=application%2Fjson-ld" title="Structured Descriptor Document (JSON-LD format)" />\n    <link rel="alternate" type="text/x-html-script-ld+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fx-html-script-ld%2Bjson" title="Structured Descriptor Document (HTML with embedded JSON-LD)" />\n    <link rel="alternate" type="text/x-html-script-turtle"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fx-html-script-turtle" title="Structured Descriptor Document (HTML with embedded Turtle)" />\n    <link rel="timegate" type="text/html" \t\t\thref="http://dbpedia.mementodepot.org/timegate/http://dbpedia.org/page/Hermann_Knoblauch" title="Time Machine" />\n    <link rel="foaf:primarytopic" \t\t\t\thref="http://dbpedia.org/resource/Hermann_Knoblauch"/>\n    <link rev="describedby" \t\t\t\t\thref="http://dbpedia.org/resource/Hermann_Knoblauch"/>\n    <!-- /Links -->\n\n    <!-- Stylesheets -->\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.1.3/css ...

# %%
res.status_code
# Out:
# 200

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<html\n    prefix="\n        dbp: http://dbpedia.org/property/\n        dbo: http://dbedia.org/ontology/\n        dct: http://purl.org/dc/terms/\n        dbd: http://dbpedia.org/datatype/\n\tog:  https://ogp.me/ns#\n\t"\n>\n\n\n<!-- header -->\n<head>\n    <meta charset="utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n\n    <title>About: Hermann Knoblauch</title>\n\n    <!-- Links -->\n    <link rel="alternate" type="application/rdf+xml" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.rdf" title="Structured Descriptor Document (RDF/XML format)" />\n    <link rel="alternate" type="text/n3" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.n3" title="Structured Descriptor Document (N3 format)" />\n    <link rel="alternate" type="text/turtle" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.ttl" title="Structured Descriptor Document (Turtle format)" />\n    <link rel="alternate" type="application/json+rdf" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.jrdf" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/json" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.json" title="Structured Descriptor Document (RDF/JSON format)" />\n    <link rel="alternate" type="application/atom+xml" \t\thref="http://dbpedia.org/data/Hermann_Knoblauch.atom" title="OData (Atom+Feed format)" />\n    <link rel="alternate" type="text/plain" \t\t\thref="http://dbpedia.org/data/Hermann_Knoblauch.ntriples" title="Structured Descriptor Document (N-Triples format)" />\n    <link rel="alternate" type="text/csv"   \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fcsv" title="Structured Descriptor Document (CSV format)" />\n    \n    <link rel="alternate" type="application/microdata+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=application%2Fmicrodata%2Bjson" title="Structured Descriptor Document (Microdata/JSON format)" />\n    <link rel="alternate" type="text/html" \t\t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fhtml" title="Structured Descriptor Document (Microdata/HTML format)" />\n    <link rel="alternate" type="application/ld+json" \t\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=application%2Fjson-ld" title="Structured Descriptor Document (JSON-LD format)" />\n    <link rel="alternate" type="text/x-html-script-ld+json"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fx-html-script-ld%2Bjson" title="Structured Descriptor Document (HTML with embedded JSON-LD)" />\n    <link rel="alternate" type="text/x-html-script-turtle"\thref="http://dbpedia.org/sparql?default-graph-uri=http%3A%2F%2Fdbpedia.org&amp;query=DESCRIBE%20%3Chttp%3A%2F%2Fdbpedia.org%2Fresource%2FHermann_Knoblauch%3E&amp;format=text%2Fx-html-script-turtle" title="Structured Descriptor Document (HTML with embedded Turtle)" />\n    <link rel="timegate" type="text/html" \t\t\thref="http://dbpedia.mementodepot.org/timegate/http://dbpedia.org/page/Hermann_Knoblauch" title="Time Machine" />\n    <link rel="foaf:primarytopic" \t\t\t\thref="http://dbpedia.org/resource/Hermann_Knoblauch"/>\n    <link rev="describedby" \t\t\t\t\thref="http://dbpedia.org/resource/Hermann_Knoblauch"/>\n    <!-- /Links -->\n\n    <!-- Stylesheets -->\n    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/bootstrap/5.1.3/css/bootstrap.min.css ...

# %%
res.status_code
# Out:
# 404

# %%
res.content
# Out:
# b'<!DOCTYPE HTML PUBLIC "-//IETF//DTD HTML//EN">\n<html>\n  <head>\n    <title>Error HTTP/1.1 404 File not found</title>\n  </head>\n  <body>\n    <h3>Error HTTP/1.1 404 File not found</h3><pre>\nThe requested URL was not found    URI  = \'/person/Hermann_Knoblauch\'\n  </pre></body></html>\n'
